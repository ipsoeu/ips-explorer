# %%
import pandas as pd

# %%
data = pd.read_excel('Updated IPS Cases.xlsx')

# %%
data.head()
# Out:
#   entry_type    rtype                                               name  \
# 0       case  Service                    AMS - public empolyment service
# 1       case  Service  Mona - Public chatbot for companies on the sub...
# 2       case  Service                     CitizenLab - Youth for Climate
# 3       case  Service  Walloon - Agricultural subsidy monitoring with...
# 4       case  Service  AcPaas - Technical procurement documents compa...
#
#                                                  url  contact  \
# 0  https://www.frontiersin.org/articles/10.3389/f...      NaN
# 1       https://www.usp.gv.at/Portal.Node/usp/public      NaN
# 2                       https://youth4climate.be/en/      NaN
# 3  https://inspire.ec.europa.eu/sites/default/fil...      NaN
# 4                https://acpaas.digipolis.be/nl/home      NaN
#
#                                          description geoextent geocoverage  \
# ...

# %%
data['id'] = data.index

# %%
data.to_csv('19-cases-update-2022.csv')
